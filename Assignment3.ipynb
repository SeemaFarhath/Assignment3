# %% [markdown]
# > <img src="attachment:vertopal_c20e2b3af8294f60893da35d44561253/media/image1.jpeg" style="width:1.62431in;height:0.8in" />
#
# YouTube:
# [<u>https://www.youtube.com/c/yogeshmurumkar</u>](https://www.youtube.com/c/yogeshmurumkar)
#
# 1.  Why are functions advantageous to have in your programs?
#
# > <u>Advantage of using functions:</u>
# >
# > It reduces code size
# >
# > Code reusability
# >
# > Avoid rewriting of the same code.
#
# 1.  When does the code in a function run: when it's specified or when
#     it's called?
#
# > When it is called.
#
# 1.  What statement creates a function?
#
# > def statement creates a function
#
# 1.  What is the difference between a function and a function call?
#
# > A function definition starts with the keyword def then the name of
# > function, whereas function call consist of only function name along
# > with argument(s) if any.
#
# 1.  How many global scopes are there in a Python program? How many local
#     scopes?
#
# > Variables which are declared within a function has local scope ie it
# > can be accessed only within the function.
# >
# > Variables which are declared outside the function any where in program
# > has global scope and can be accesses from any point in the program or
# > within function.
#
# 1.  What happens to variables in a local scope when the function call
#     returns?
#
# > Variables can destroyed after the function call return.It will not
# > remember the previous value when next time the function is called..
#
# 1.  What is the concept of a return value? Is it possible to have a
#     return value in an expression?
#
# Return value is used to send the result back to the calling function..
#
# Yes,it is possible ,we can use return values in an expression..
#
# 1.  If a function does not have a return statement, what is the return
#     value of a call to that function?
#
# > If a function does not have any return value ,then the return type
# > will be **void**
#
# 1.  How do you make a function variable refer to the global variable?
#
# > Using the keyword **global as a prefix to global variable name**
#
# 1.  What is the data type of None?
#
# > Nonetype
#
# 1.  What does the sentence import areallyourpetsnamederic do?
#
# 2.  If you had a bacon() feature in a spam module, what would you call
#     it after importing spam?
#
# > Spam.bacon()
#
# 1.  What can you do to save a programme from crashing if it encounters
#     an error?
#
# > By using try block, we can save a program from crashing ..
#
# 1.  What is the purpose of the try clause? What is the purpose of the
#     except clause?
#
# The try block is used to check some code for errors i.e the code inside
# the try block will execute when there is no error in the program.
# Whereas the code inside the except block will execute whenever the
# program encounters some error in the preceding try block.
